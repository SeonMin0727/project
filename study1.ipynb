# %%
import csv
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

for row in data :
    print(row)
# Out:
# ['\ufeff사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['44927 ', '1호선', '150 ', '서울역', '1228346 ', '1173888 ', '171270 ', '161413 ']
# ['44927 ', '1호선', '151 ', '시청', '566559 ', '580516 ', '76126 ', '73149 ']
# ['44927 ', '1호선', '152 ', '종각', '885821 ', '862251 ', '125085 ', '117231 ']
# ['44927 ', '1호선', '153 ', '종로3가', '447641 ', '411958 ', '271449 ', '251592 ']
# ['44927 ', '1호선', '154 ', '종로5가', '428412 ', '424366 ', '217290 ', '209180 ']
# ['44927 ', '1호선', '155 ', '동대문', '210265 ', '198163 ', '104059 ', '102142 ']
# ['44927 ', '1호선', '156 ', '신설동', '256664 ', '248625 ', '104780 ', '100582 ']
# ['44927 ', '1호선', '157 ', '제기동', '221450 ', '215567 ', '266914 ', '289322 ']
# ['44927 ', '1호선', '158 ', '청량리(서울시립대입구)', '309342 ', '305961 ', '242454 ', '243890 ']
# ['44927 ', '1호선', '159 ', '동묘앞', '118696 ', '125235 ', '129707 ', '132735 ']
# ['44927 ', '2호선', '201 ', '시청', '585786 ', '558820 ', '49461 ', '45261 ']
# ...

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    print(row)
# Out:
# ['44927 ', '1호선', '150 ', '서울역', 1228346, 1173888, 171270, 161413]
# ['44927 ', '1호선', '151 ', '시청', 566559, 580516, 76126, 73149]
# ['44927 ', '1호선', '152 ', '종각', 885821, 862251, 125085, 117231]
# ['44927 ', '1호선', '153 ', '종로3가', 447641, 411958, 271449, 251592]
# ['44927 ', '1호선', '154 ', '종로5가', 428412, 424366, 217290, 209180]
# ['44927 ', '1호선', '155 ', '동대문', 210265, 198163, 104059, 102142]
# ['44927 ', '1호선', '156 ', '신설동', 256664, 248625, 104780, 100582]
# ['44927 ', '1호선', '157 ', '제기동', 221450, 215567, 266914, 289322]
# ['44927 ', '1호선', '158 ', '청량리(서울시립대입구)', 309342, 305961, 242454, 243890]
# ['44927 ', '1호선', '159 ', '동묘앞', 118696, 125235, 129707, 132735]
# ['44927 ', '2호선', '201 ', '시청', 585786, 558820, 49461, 45261]
# ['44927 ', '2호선', '202 ', '을지로입구', 1103017, 1132715, 92071, 86397]
# ['44927 ', '2호선', '203 ', '을지로3가', 549488, 555415, 70676, 69456]
# ['44927 ', '2호선', '204 ', '을지로4가', 274018, 281698, 72790, 71775]
# ...

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)
mx = 0
rate = 0

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    rate = row[4] / row[6]
    if rate > mx :
        mx = rate
print(mx)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 11
#       9 for i in range(4, 8) :
#      10     row[i] = int(row[i])
# ---> 11 rate = row[4] / row[6]
#      12 if rate > mx :
#      13     mx = rate
#
# ZeroDivisionError: division by zero

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)
mx = 0
rate = 0

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    if row[6] == 0 :
        print(row)
# Out:
# ['44927 ', '경원선', '1022 ', '창동', 17, 0, 0, 0]
# ['44927 ', '일산선', '1949 ', '지축', 8, 0, 0, 0]
# ['44927 ', '경의선', '1296 ', '계양', 6, 0, 0, 0]
# ['44927 ', '경의선', '1297 ', '검암', 2, 0, 0, 0]
# ['44927 ', '6호선', '2649 ', '신내', 4, 0, 0, 0]

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)

mx = 0
rate = 0

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    if row[6] != 0 and (row[4] + row[6]) > 100000 :
        rate = row[4] / (row[4] + row[6])
        if rate > mx :
            mx = rate
            print(row, round(rate, 2))
# Out:
# ['44927 ', '1호선', '150 ', '서울역', 1228346, 1173888, 171270, 161413] 0.88
# ['44927 ', '1호선', '151 ', '시청', 566559, 580516, 76126, 73149] 0.88
# ['44927 ', '2호선', '201 ', '시청', 585786, 558820, 49461, 45261] 0.92
# ['44927 ', '2호선', '202 ', '을지로입구', 1103017, 1132715, 92071, 86397] 0.92
# ['44927 ', '2호선', '209 ', '한양대', 187650, 198011, 11297, 11818] 0.94
# ['44927 ', '2호선', '239 ', '홍대입구', 1796107, 1894987, 84934, 81345] 0.95
# ['44927 ', '경부선', '1001 ', '서울역', 254560, 74191, 12036, 2710] 0.95
# ['44927 ', '공항철도 1호선', '4203 ', '홍대입구', 354648, 358941, 16525, 15278] 0.96

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)

mx = 0
rate = 0

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    if row[6] != 0 and (row[4] + row[6]) > 100000 :
        rate = row[4] / (row[4] + row[6])
        if rate > 0.94 :
            mx = rate
            print(row, round(rate, 2))
# Out:
# ['44927 ', '2호선', '209 ', '한양대', 187650, 198011, 11297, 11818] 0.94
# ['44927 ', '2호선', '239 ', '홍대입구', 1796107, 1894987, 84934, 81345] 0.95
# ['44927 ', '경부선', '1001 ', '서울역', 254560, 74191, 12036, 2710] 0.95
# ['44927 ', '6호선', '2632 ', '한강진', 227022, 259668, 13964, 14051] 0.94
# ['44927 ', '9호선', '4125 ', '신논현', 800307, 791475, 47640, 45843] 0.94
# ['44927 ', '공항철도 1호선', '4203 ', '홍대입구', 354648, 358941, 16525, 15278] 0.96
# ['44927 ', '공항철도 1호선', '4206 ', '마곡나루(서울식물원)', 247108, 237359, 13239, 13957] 0.95

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)

mx = 0
rate = 0

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    if row[6] != 0 and (row[4] + row[6]) > 100000 :
        rate = row[4] / (row[4] + row[6])
        if rate > mx :
            mx = rate
            mx_station = row[3] + ' ' + row[1]

print(mx_station, round(mx * 100,2))
# Out:
# 홍대입구 공항철도 1호선 95.55

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)

mx = [0] * 4
mx_station = [''] * 4

label = ['유임승차', '유임하차', '무임승차', '무임하차']

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
        if row[i] > mx[i-4] :
            mx[i-4] = row[i]
            mx_station[i-4] = row[3] + ' ' + row[1]

for i in range(4) :
    print(label[i] + ' : ' + mx_station[i], mx[i])
# Out:
# 유임승차 : 강남 2호선 2075004
# 유임하차 : 강남 2호선 2017884
# 무임승차 : 종로3가 1호선 271449
# 무임하차 : 제기동 1호선 289322

# %%
import csv
import matplotlib.pyplot as plt

f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)

next(data)

label = ['유임승차', '유임하차', '무임승차', '무임하차']

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
        
plt.pie(row[4:8])
plt.axis('equal')
plt.show()

# %%
f = open('C:/Users/user/Desktop/pythonproblem/subwayfee.csv', encoding='utf-8')
data = csv.reader(f)
next(data)

label = ['유임승차', '유임하차', '무임승차', '무임하차']
c = ['#14CCC0', '#389993', '#FF1C6A', '#CC14AF']

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i])
    
plt.rcParams['font.family'] = 'NanumGothic'
plt.figure(dpi = 300)
plt.title(row[3] + ' ' + row[1])
plt.pie(row[4:8], labels = label, colors = c, autopct = '%1.f%%')
plt.axis('equal')
plt.show()
